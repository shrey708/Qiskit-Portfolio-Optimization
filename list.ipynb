# %%
import pandas as pd

# %%
d = pd.read_csv('list.csv')
d
# Out:
#    Symbol                                  Name   Price  change  change.1  \
# 0     WMT                           Walmart Inc  139.65    0.24      0.17
# 1     WBA          Walgreens Boots Alliance Inc   35.43    0.74      2.13
# 2      VZ            Verizon Communications Inc   36.35    0.38      1.06
# 3       V                              Visa Inc  195.08    4.37      2.29
# 4     UNH                UnitedHealth Group Inc  537.91   -3.69     -0.68
# 5     TRV               Travelers Companies Inc  176.35   -3.44     -1.91
# 6      PG                   Procter & Gamble Co  130.78    1.41      1.09
# 7     NKE                              Nike Inc   91.74    3.73      4.24
# 8    MSFT                        Microsoft Corp  249.73    2.48      1.00
# 9     MRK                        Merck & Co Inc   97.99    0.62      0.64
# 10    MMM                                 3M Co  117.99   -0.39     -0.33
# 11    MCD                       McDonald's Corp  256.65    1.33      0.52
# ...

# %%
k = d['Symbol']
k
# Out:
# 0      WMT
# 1      WBA
# 2       VZ
# 3        V
# 4      UNH
# 5      TRV
# 6       PG
# 7      NKE
# 8     MSFT
# 9      MRK
# 10     MMM
# 11     MCD
# 12      KO
# 13     JPM
# 14     JNJ
# 15    INTC
# 16     IBM
# 17     HON
# 18      HD
# 19      GS
# 20     DOW
# 21     DIS
# 22     CVX
# 23    CSCO
# 24     CRM
# 25     CAT
# 26      BA
# 27     AXP
# 28    AMGN
# 29    AAPL
# Name: Symbol, dtype: object

# %%
l = k.tolist()
l
# Out:
# ['WMT',
#  'WBA',
#  'VZ',
#  'V',
#  'UNH',
#  'TRV',
#  'PG',
#  'NKE',
#  'MSFT',
#  'MRK',
#  'MMM',
#  'MCD',
#  'KO',
#  'JPM',
#  'JNJ',
#  'INTC',
#  'IBM',
#  'HON',
#  'HD',
#  'GS',
#  'DOW',
#  'DIS',
#  'CVX',
#  'CSCO',
#  'CRM',
#  'CAT',
#  'BA',
#  'AXP',
#  'AMGN',
#  'AAPL']

# %%
 asset = ['WMT','WBA', 'VZ', 'V', 'UNH', 'TRV', 'PG', 'NKE', 'MSFT',  'MRK',  'MMM', 'MCD', 'KO', 'JPM', 'JNJ', 'INTC', 'IBM', 'HON', 'HD', 'GS', 'DOW', 'DIS', 'CVX', 'CSCO', 'CRM', 'CAT', 'BA', 'AXP', 'AMGN', 'AAPL']

# %%
asset
# Out:
# ['WMT',
#  'WBA',
#  'VZ',
#  'V',
#  'UNH',
#  'TRV',
#  'PG',
#  'NKE',
#  'MSFT',
#  'MRK',
#  'MMM',
#  'MCD',
#  'KO',
#  'JPM',
#  'JNJ',
#  'INTC',
#  'IBM',
#  'HON',
#  'HD',
#  'GS',
#  'DOW',
#  'DIS',
#  'CVX',
#  'CSCO',
#  'CRM',
#  'CAT',
#  'BA',
#  'AXP',
#  'AMGN',
#  'AAPL']
