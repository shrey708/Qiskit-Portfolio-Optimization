# %%
# !pip install qiskit
# Out:
# Requirement already satisfied: qiskit in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (0.38.0)
# Requirement already satisfied: qiskit-terra==0.21.2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit) (0.21.2)
# Requirement already satisfied: qiskit-aer==0.11.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit) (0.11.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.19.2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit) (0.19.2)
# Requirement already satisfied: numpy>=1.16.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-aer==0.11.0->qiskit) (1.23.2)
# Requirement already satisfied: scipy>=1.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-aer==0.11.0->qiskit) (1.9.1)
# Requirement already satisfied: urllib3>=1.21.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.26.12)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.1.0)
# Requirement already satisfied: websockets>=10.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (10.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.8.2)
# Requirement already satisfied: requests>=2.19 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (2.28.1)
# Requirement already satisfied: websocket-client>=1.0.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit) (1.4.1)
# Requirement already satisfied: sympy>=1.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (1.11.1)
# Requirement already satisfied: dill>=0.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (0.3.5.1)
# Requirement already satisfied: ply>=3.10 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (3.11)
# Requirement already satisfied: retworkx>=0.11.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (0.11.0)
# Requirement already satisfied: symengine>=0.9 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (0.9.2)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (1.1.1)
# Requirement already satisfied: stevedore>=3.0.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (4.0.0)
# Requirement already satisfied: psutil>=5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra==0.21.2->qiskit) (5.9.2)
# Requirement already satisfied: six>=1.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit) (2022.6.15)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (38.0.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from stevedore>=3.0.0->qiskit-terra==0.21.2->qiskit) (5.10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra==0.21.2->qiskit) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (1.15.1)
# Requirement already satisfied: pycparser in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit) (2.21)

# %%
# !pip install qiskit-finance
# Out:
# Requirement already satisfied: qiskit-finance in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (0.3.4)
# Requirement already satisfied: qiskit-optimization>=0.2.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (0.4.0)
# Requirement already satisfied: qiskit-terra>=0.20.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (0.21.2)
# Requirement already satisfied: fastdtw in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (0.3.4)
# Requirement already satisfied: numpy>=1.17 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (1.23.2)
# Requirement already satisfied: setuptools>=40.1.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (63.4.1)
# Requirement already satisfied: scipy>=1.4 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (1.9.1)
# Requirement already satisfied: nasdaq-data-link in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (1.0.4)
# Requirement already satisfied: yfinance>=0.1.70 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (0.1.74)
# Requirement already satisfied: certifi in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (2022.6.15)
# Requirement already satisfied: urllib3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (1.26.12)
# Requirement already satisfied: pandas in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (1.4.4)
# Requirement already satisfied: psutil>=5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-finance) (5.9.2)
# Requirement already satisfied: networkx>=2.2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-optimization>=0.2.0->qiskit-finance) (2.8.6)
# Requirement already satisfied: docplex>=2.21.207 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-optimization>=0.2.0->qiskit-finance) (2.23.222)
# Requirement already satisfied: dill>=0.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (0.3.5.1)
# Requirement already satisfied: retworkx>=0.11.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (0.11.0)
# Requirement already satisfied: ply>=3.10 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (3.11)
# Requirement already satisfied: sympy>=1.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (1.11.1)
# Requirement already satisfied: symengine>=0.9 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (0.9.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (4.0.0)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.20.0->qiskit-finance) (1.1.1)
# Requirement already satisfied: multitasking>=0.0.7 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance>=0.1.70->qiskit-finance) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance>=0.1.70->qiskit-finance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance>=0.1.70->qiskit-finance) (2.28.1)
# Requirement already satisfied: pytz>=2020.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from pandas->qiskit-finance) (2022.2.1)
# Requirement already satisfied: inflection>=0.3.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from nasdaq-data-link->qiskit-finance) (0.5.1)
# Requirement already satisfied: more-itertools in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from nasdaq-data-link->qiskit-finance) (8.14.0)
# Requirement already satisfied: six in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from nasdaq-data-link->qiskit-finance) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance>=0.1.70->qiskit-finance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance>=0.1.70->qiskit-finance) (3.3)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.20.0->qiskit-finance) (5.10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra>=0.20.0->qiskit-finance) (1.2.1)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (0.1.74)
# Requirement already satisfied: multitasking>=0.0.7 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=0.24.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.26 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: numpy>=1.15 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (1.23.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: six>=1.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)

# %%
#importing the required stuff
from qiskit import Aer
from qiskit.algorithms import VQE, QAOA, NumPyMinimumEigensolver
from qiskit.algorithms.optimizers import COBYLA, SPSA
from qiskit.circuit.library import TwoLocal
from qiskit.utils import QuantumInstance
from qiskit_finance.applications.optimization import PortfolioOptimization
from qiskit_finance.data_providers import *
from qiskit_finance import QiskitFinanceError
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit_optimization.applications import OptimizationApplication
from qiskit_optimization.converters import QuadraticProgramToQubo
import numpy as np
import matplotlib.pyplot as plt

import datetime
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import csv
import yfinance as yf
import pandas_datareader.data as web
from qiskit_finance.applications.optimization import PortfolioDiversification

# %%
# %matplotlib inline

# %%
# assets = ["AAPL", "GS", "JPM", "MSFT", "MCD", "WMT"]
# assets = ["AMZN", "BAC", "CVX", "SPY"]

# %%
# set number of assets (= number of qubits)

seed = 123

assets= ["JPM", "GS", "MSFT", "AAPL", "WMT", "MCD"]

# Using data from yahoo finance
# use the name listed for particular company that you wish to add

import yfinance as yf
import numpy as np
selected_stocks_data = yf.download(assets, start = '2013-01-01', end = '2021-12-31')['Adj Close']
selected_stocks_data.head()
log_return = np.log(selected_stocks_data/selected_stocks_data.shift(1))
# np.log(data/data.shift(1))
# log_return.head()


num_assets = len(assets)
mu = log_return.mean()*252
sigma = log_return.cov()*252
sigma = np.array(sigma)
mu = np.array(mu)
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
log_return
# Out:
#                 AAPL        GS       JPM       MCD      MSFT       WMT
# Date
# 2012-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2013-01-02  0.031189  0.031636  0.022417  0.021421  0.033502  0.014694
# 2013-01-03 -0.012702 -0.005484 -0.002017  0.005643 -0.013487 -0.006375
# 2013-01-04 -0.028250  0.026899  0.017570 -0.008644 -0.018893  0.003772
# 2013-01-07 -0.005900 -0.001860  0.001101  0.011728 -0.001871 -0.009603
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-23  0.003637  0.007063  0.003567  0.003805  0.004462 -0.002220
# 2021-12-27  0.022715  0.007761  0.005707  0.008574  0.022921  0.009063
# 2021-12-28 -0.005784 -0.001109  0.003030 -0.001343 -0.003510  0.014249
# 2021-12-29  0.000502 -0.003644 -0.000504  0.002274  0.002049 -0.000490
# 2021-12-30 -0.006600 -0.001762 -0.000505 -0.004779 -0.007721  0.003218
#
# [2267 rows x 6 columns]

# %%
selected_stocks_data.head() # yf
# Out:
#                  AAPL          GS        JPM        MCD       MSFT        WMT
# Date
# 2012-12-31  16.372108  108.482590  33.315800  67.443237  22.086391  54.851315
# 2013-01-02  16.890789  111.969414  34.071075  68.903557  22.838867  55.663261
# 2013-01-03  16.677601  111.357086  34.002415  69.293503  22.532913  55.309555
# 2013-01-04  16.213051  114.393173  34.605110  68.697113  22.111198  55.518570
# 2013-01-07  16.117678  114.180550  34.643242  69.507568  22.069859  54.987976

# %%
print("returns ", mu)
print("cov ", sigma)
# Out:
# returns  [0.26503347 0.13884455 0.16998562 0.15126842 0.30309725 0.10537873]
# cov  [[0.08008179 0.03523639 0.03017364 0.02156272 0.04354194 0.01714487]
#  [0.03523639 0.07732769 0.06179028 0.02574528 0.03512863 0.01526533]
#  [0.03017364 0.06179028 0.06980337 0.0256304  0.03211164 0.01472568]
#  [0.02156272 0.02574528 0.0256304  0.0395305  0.02406794 0.01254758]
#  [0.04354194 0.03512863 0.03211164 0.02406794 0.06743191 0.01844791]
#  [0.01714487 0.01526533 0.01472568 0.01254758 0.01844791 0.03879353]]

# %%
# data = YahooDataProvider(
#         tickers= assets , 
#         start=datetime.datetime(2011, 1, 1),
#         end=datetime.datetime(2015, 12, 31),
#     )

# num_assets = len(assets)
# data.run()

# muu = data.get_period_return_mean_vector()
# sigmaa = data.get_period_return_covariance_matrix()
# rho = data.get_similarity_matrix()
# print(muu)
# print(sigmaa)

# %%
# data.heed()

# %%
# plot sigma
plt.imshow(sigma, interpolation="nearest")
plt.show()

# %%
q = 0.5  # set risk factor
budget = num_assets // 2  # set budget
penalty = num_assets  # set parameter to scale the budget penalty term

portfolio = PortfolioOptimization(
    expected_returns=mu, covariances=sigma, risk_factor=q, budget=budget,
)
qp = portfolio.to_quadratic_program()
qp
# Out:
# <QuadraticProgram: minimize 0.04004089608196366*x_0^2 + 0.03523638507935903*x_..., 6 variables, 1 constraints, 'Portfolio optimization'>

# %%
model =qp
# # model.minimize(linear=linear, quadratic=quadratic)
# operators , offset= model.to_ising()
# operators

# %%
def index_to_selection(i, num_assets):
    s = "{0:b}".format(i).rjust(num_assets)
    x = np.array([1 if s[i] == "1" else 0 for i in reversed(range(num_assets))])
    return x


def print_result(result,fname):
    
    f = open(fname, 'w')
    header = ['SELECTION', 'VALUE', 'PROBABLITY']
    writer = csv.writer(f)
    writer.writerow(header)
    
    selection = result.x
    value = result.fval
    print("Optimal: selection {}, value {:.4f}".format(selection, value))

    # eigenstate = result.min_eigen_solver_result.eigenstate
    # eigenvector = eigenstate if isinstance(eigenstate, np.ndarray) else eigenstate.to_matrix()
    # probabilities = np.abs(eigenvector) ** 2
    # i_sorted = reversed(np.argsort(probabilities))
    # print("\n----------------- Full result ---------------------")
    # print("selection\tvalue\t\tprobability")
    # print("---------------------------------------------------")
    # for i in i_sorted:
    #     x = index_to_selection(i, num_assets)
    #     value = QuadraticProgramToQubo().convert(qp).objective.evaluate(x)
    #     value = portfolio.to_quadratic_program().objective.evaluate(x)
    #     probability = probabilities[i]
    #     row = [x, value, probability]
    #     writer.writerow(row)
    #     # print("%10s\t%.4f\t\t%.4f" % (x, value, probability))
    f.close()

# %%
#classical reference solution
#provide fname ='complete address/location of your .csv file'

# exact_mes = NumPyMinimumEigensolver()
# exact_eigensolver = MinimumEigenOptimizer(exact_mes)

exact = MinimumEigenOptimizer(NumPyMinimumEigensolver())
result = exact.solve(model)
best_sample = result.x
best_sample
# [1. 0. 0. 1]
# Out:
# array([1., 0., 0., 1., 1., 0.])

# %%
# !pip install qiskit-aer
# Out:
# Requirement already satisfied: qiskit-aer in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: qiskit-terra>=0.21.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-aer) (0.21.2)
# Requirement already satisfied: numpy>=1.16.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-aer) (1.23.2)
# Requirement already satisfied: scipy>=1.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-aer) (1.9.1)
# Requirement already satisfied: psutil>=5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (5.9.2)
# Requirement already satisfied: symengine>=0.9 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (0.9.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (2.8.2)
# Requirement already satisfied: retworkx>=0.11.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (0.11.0)
# Requirement already satisfied: dill>=0.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (0.3.5.1)
# Requirement already satisfied: ply>=3.10 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (3.11)
# Requirement already satisfied: sympy>=1.3 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (1.11.1)
# Requirement already satisfied: stevedore>=3.0.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (4.0.0)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (1.1.1)
# Requirement already satisfied: six>=1.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.21.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.21.0->qiskit-aer) (5.10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from sympy>=1.3->qiskit-terra>=0.21.0->qiskit-aer) (1.2.1)

# %%
# VQE with Cobyla solution
#provide fname ='complete address/location of your .csv file'

from qiskit.utils import algorithm_globals

algorithm_globals.random_seed = 1234
backend = Aer.get_backend("qasm_simulator")

cobyla = COBYLA()
cobyla.set_options(maxiter=500)
ry = TwoLocal(num_assets, "ry", "cz", reps=3, entanglement="full")
quantum_instance = QuantumInstance(backend=backend, shots=8192) 
vqe_mes = VQE(ry, optimizer=cobyla, quantum_instance=quantum_instance)
vqe = MinimumEigenOptimizer(vqe_mes)
result = vqe.solve(qp)
result = result.x
result

#[0. 0. 1. 1. 0. 1.] --numpy eigen solver
# Out:
# vqe result type  <class 'qiskit.algorithms.minimum_eigen_solvers.vqe.VQEResult'>
# array([1., 0., 0., 1., 1., 0.])

# %%
# VQE with SPSA solution
#provide fname ='complete address/location of your .csv file'

from qiskit.utils import algorithm_globals

algorithm_globals.random_seed = 1234
backend = Aer.get_backend("qasm_simulator")

cobyla = SPSA()
cobyla.set_options(maxiter=500)
ry = TwoLocal(num_assets, "ry", "cz", reps=3, entanglement="full")
# quantum_instance = QuantumInstance(backend=backend, shots=8192, seed_simulator=seed, seed_transpiler=seed)
quantum_instance = QuantumInstance(backend=backend, shots=8192) 
vqe_mes = VQE(ry, optimizer=cobyla, quantum_instance=quantum_instance)
vqe = MinimumEigenOptimizer(vqe_mes)
result = vqe.solve(qp)
result = result.x
result
# fname = 'vqe1.csv' #change the location and name of .csv file
# print_result(result, fname)
# print(result)

#[0. 0. 1. 1. 0. 1.] --numpy eigen solver
# Out:
# vqe result type  <class 'qiskit.algorithms.minimum_eigen_solvers.vqe.VQEResult'>
# array([1., 0., 0., 1., 1., 0.])

# %%
# QAOA solution
#provide fname ='complete address/location of your .csv file'

algorithm_globals.random_seed = 1234
backend = Aer.get_backend("statevector_simulator")

cobyla = COBYLA()
cobyla.set_options(maxiter=250)
# quantum_instance = QuantumInstance(backend=backend, shots=8192, seed_simulator=seed, seed_transpiler=seed)
quantum_instance = QuantumInstance(backend=backend, shots=8192) 
qaoa_mes = QAOA(optimizer=cobyla, reps=3, quantum_instance=quantum_instance)
qaoa = MinimumEigenOptimizer(qaoa_mes)
result = qaoa.solve(qp)
result = result.x
result

# [0. 0. 1. 1. 0. 1.] -numpy exact solver
# Out:
# vqe result type  <class 'qiskit.algorithms.minimum_eigen_solvers.vqe.VQEResult'>
# array([1., 0., 0., 0., 1., 1., 1., 0.])

# %%
# QAOA wth SPSA solution
#provide fname ='complete address/location of your .csv file'

algorithm_globals.random_seed = 1234
backend = Aer.get_backend("statevector_simulator")

cobyla = SPSA()
cobyla.set_options(maxiter=250)
# quantum_instance = QuantumInstance(backend=backend, shots=8192, seed_simulator=seed, seed_transpiler=seed)
quantum_instance = QuantumInstance(backend=backend, shots=8192) 
qaoa_mes = QAOA(optimizer=cobyla, reps=3, quantum_instance=quantum_instance)
qaoa = MinimumEigenOptimizer(qaoa_mes)
result = qaoa.solve(qp)
result = result.x
result

# [0. 0. 1. 1. 0. 1.] -numpy exact solver
# Out:
# vqe result type  <class 'qiskit.algorithms.minimum_eigen_solvers.vqe.VQEResult'>
# array([1., 0., 0., 0., 1., 1., 1., 0.])

# %% [markdown]
# #### weight allocation part after asset selection using quantum

# %%
selected_assets = [1, 0, 0, 1, 1, 0]
assets = ["JPM", "GS", "MSFT", "AAPL", "WMT", "MCD"]
# assets = ["AMZN", "BAC", "CVX", "SPY"]

selected_bitstring = [i for i, e in enumerate(selected_assets) if e == 1]
# print(selected_bitstring)
my_assets = [assets[i] for i in selected_bitstring]
print("your lucky assets are ",my_assets)
# Out:
# your lucky assets are  ['JPM', 'AAPL', 'WMT']

# %%
import yfinance as yf
import numpy as np
selected_stocks_data = yf.download(my_assets, start = '2013-01-01', end = '2021-12-31')['Adj Close']
selected_stocks_data.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#                  AAPL        JPM        WMT
# Date
# 2012-12-31  16.372103  33.315804  54.851326
# 2013-01-02  16.890800  34.071075  55.663269
# 2013-01-03  16.677599  34.002422  55.309547
# 2013-01-04  16.213053  34.605110  55.518562
# 2013-01-07  16.117674  34.643250  54.987976

# %%
log_retrn = np.log(selected_stocks_data/selected_stocks_data.shift(1))
log_return.head()
# Out:
#                 AAPL       JPM       WMT
# Date
# 2012-12-31       NaN       NaN       NaN
# 2013-01-02  0.031190  0.022417  0.014694
# 2013-01-03 -0.012703 -0.002017 -0.006375
# 2013-01-04 -0.028250  0.017570  0.003772
# 2013-01-07 -0.005900  0.001102 -0.009603

# %%
import numpy as np
weights = np.array(np.random.random(len(my_assets)))

print('normalised weights :')
weights = weights/np.sum(weights)
print(weights)
# Out:
# normalised weights :
# [0.35015332 0.42831462 0.22153207]

# %%
from scipy.optimize import minimize

def get_ret_vol_sr(weights): 
    weights = np.array(weights)
    ret = np.sum(log_return.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T,np.dot(log_return.cov()*252,weights)))
    sr = ret/vol 
    return np.array(sr)

# minimize negative Sharpe Ratio
def neg_sharpe(weights): 
    return get_ret_vol_sr(weights)*-1

# check allocation sums to 1
def check_sum(weights): 
    return np.sum(weights) - 1

# %%
# create constraint variable
cons = ({'type':'eq','fun':check_sum})

# %%
# create weight boundaries
bounds = tuple((0, 1) for stocks in range(len(my_assets)))

# %%
# initial guess
# init_guess = [0.1 for stocks in range(len(my_assets))]
init_guess = [0.3, 0.4, 0.3]
# tuple((0, 1) for stocks in range(len(my_assets)))

# %%
neg_sharpe(weights)
# Out:
# -0.9564019357717465

# %%
import numpy as np, numpy.random
a = np.random.dirichlet(np.ones(10),size=1)
print(a)
print(np.sum(a))
# Out:
# [[0.02654458 0.02233132 0.32347013 0.12892365 0.02265497 0.01454822
#   0.09560971 0.06533636 0.18422282 0.11635824]]
# 0.9999999999999999

# %%
# from scipy.optimize import minimize
opt_results = minimize(neg_sharpe, init_guess, method='SLSQP', bounds=bounds, constraints=cons)
opt_results
# Out:
#      fun: -1.002717329015049
#      jac: array([ 3.08603048e-05,  2.27868557e-04, -2.80648470e-04])
#  message: 'Optimization terminated successfully'
#     nfev: 20
#      nit: 5
#     njev: 5
#   status: 0
#  success: True
#        x: array([0.55110358, 0.21429026, 0.23460616])

# %%
my_weights = np.array(opt_results.x)
my_weights = my_weights.tolist()

# %%
tot_weights = np.sum(my_weights)
tot_weights
# Out:
# 1.0

# %%
weights_alloc = dict(zip(my_assets, my_weights))
weights_alloc
# Out:
# {'JPM': 0.5511035761482559,
#  'AAPL': 0.21429025930119963,
#  'WMT': 0.2346061645505445}

# %%
weights_alloc.values()
# Out:
# dict_values([0.5511035761482559, 0.21429025930119963, 0.2346061645505445])

# %%
my_weights
# Out:
# [0.5511035761482559, 0.21429025930119963, 0.2346061645505445]

# %%
my_assets
# Out:
# ['JPM', 'AAPL', 'WMT']

# %%
ret = np.sum(log_return.mean() * my_weights) * 252 # returns of a portfolio after optimum weight allocation
vol = np.sqrt(np.dot(weights.T,np.dot(log_return.cov()*252,my_weights))) # risk of a portfolio after optimum weight allocation
sharpe_ratio = ret/vol # sharpe ratio of a portfolio after optimum weight allocation
print("sharpe ratio of your porrtfolio after optimization is ", sharpe_ratio)

risk_ret_dict_of_quantum = {
    'returns' : ret*100,
    'risk' : vol*100, 
    'sharpe_ratio' : sharpe_ratio 
}
# Out:
# sharpe ratio of your porrtfolio after optimization is  1.0500113452308073

# %%
risk_ret_dict_of_quantum
# Out:
# {'returns': 20.72096658569336,
#  'risk': 19.73404066518786,
#  'sharpe_ratio': 1.0500113452308073}

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array(weights)
mylabels = my_assets

plt.pie(y, labels = mylabels)
plt.show()

# %%
# 4_stocks= ["JPM", "GS", "MSFT", "WMT"]
# 6_stocks= ["JPM", "GS", "MSFT", "AAPL", "WMT", "MCD"]
# 8_stocks= ["JPM", "GS", "MSFT", "AAPL", "KO", "WMT", "MCD", "NKE"]
# 10_stocks=["JPM", "GS", "MSFT", "AAPL", "KO", "WMT", "DIS", "BA", "MCD", "NKE"]

# %% [markdown]
# ## MPT CODE to benchmark

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (0.1.74)
# Requirement already satisfied: numpy>=1.15 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (1.23.2)
# Requirement already satisfied: pandas>=0.24.0 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.5.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from requests>=2.26->yfinance) (1.26.12)
# Requirement already satisfied: six>=1.5 in /home/sangram/anaconda3/envs/quantum-qiskit/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import scipy.optimize as optimization

# %%
NUM_TRADING_DAYS = 252 #252*5 cosnidered previously, now I'm just taing for 1 year
NUM_PORTFOLIOS = 10000
stocks = ["JPM", "GS", "MSFT", "AAPL", "WMT", "MCD"]
# stocks = ["AMZN", "BAC", "CVX", "SPY"]

# %%
start_date = '2013-01-01' # YY/MM/DD
end_date = '2021-12-31'   # YY/MM/DD

# %%
def download_data():
    stocks_data = yf.download(stocks, start = '2011-1-1', end = '2015-12-31')['Adj Close']
    # stocks_data.head()
    return pd.DataFrame(stocks_data)

# %%
def show_data(data):
    data.plot(figsize=(8, 5))
    plt.show()

# show_data(data)

# %%
def calculate_return(data):
    log_return = np.log(data / data.shift(1))
    return log_return[1:]

# %%
def show_statistics(returns):
    print(returns.mean() * NUM_TRADING_DAYS)
    print(returns.cov() * NUM_TRADING_DAYS)

# %%
def show_mean_variance(returns, weights):
    portfolio_return = np.sum(returns.mean() * weights) * NUM_TRADING_DAYS
    portfolio_volatility = np.sqrt(np.dot(weights, np.dot(returns.cov() * NUM_TRADING_DAYS, weights)))
    print('Expected portfolio mean: ', portfolio_return)
    print('Expected portfolio volatility: ', portfolio_volatility)
    print("sharpe ratio of a portfolio is ", portfolio_return/portfolio_volatility)

# %%
def show_portfolios(returns, volatilities):
    plt.figure(figsize=(8, 5))
    plt.scatter(volatilities, returns, c=returns / volatilities, marker='o')
    plt.grid(True)
    plt.xlabel('Expected Volatility')
    plt.ylabel('Expected Return')
    plt.colorbar(label='Sharpe Ratio')
    plt.show()

# %%
def generate_portfolios(returns):
    portfolio_means = []
    portfolio_risks = []
    portfolio_weights = []

# %%
def generate_portfolios(returns):
    portfolio_means = []
    portfolio_risks = []
    portfolio_weights = []

    for _ in range(NUM_PORTFOLIOS):
        w = np.random.random(len(stocks))
        w /= np.sum(w)
        portfolio_weights.append(w)
        portfolio_means.append(np.sum(returns.mean() * w) * NUM_TRADING_DAYS)
        portfolio_risks.append(np.sqrt(np.dot(w.T, np.dot(returns.cov() * NUM_TRADING_DAYS, w))))

    return np.array(portfolio_weights), np.array(portfolio_means), np.array(portfolio_risks)

# %%
def statistics(weights, returns):
    portfolio_return = np.sum(returns.mean() * weights) * NUM_TRADING_DAYS
    portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov() * NUM_TRADING_DAYS, weights)))

    return np.array([portfolio_return, portfolio_volatility, portfolio_return / portfolio_volatility])

# %%
def min_function_sharpe(weights, returns):
    return -statistics(weights, returns)[2]

# %%
def optimize_portfolio(weights, returns):
    constraints = {'type': 'eq', 'fun': lambda x: np.sum(x) - 1}
    bounds = tuple((0, 1) for _ in range(len(stocks)))
    return optimization.minimize(fun=min_function_sharpe, x0=weights[0], args=returns, method='SLSQP',
                                 bounds=bounds, constraints=constraints)

# %%
def print_optimal_portfolio(optimum, returns):
    print('Optimal Portfolio: ', optimum['x'].round(3))
    print('Expected return, volatility and sharpe ratio: ', statistics(optimum['x'].round(3), returns))

# %%
def show_optimal_portfolio(opt, rets, portfolio_rets, portfolio_vols):
    plt.figure(figsize=(8, 5))
    plt.scatter(portfolio_vols, portfolio_rets, c=portfolio_rets / portfolio_vols, marker='o')
    plt.grid(True)
    plt.xlabel('Expected Volatility')
    plt.ylabel('Expected Return')
    plt.colorbar(label='Sharpe Ratio')
    plt.plot(statistics(opt['x'], rets)[1], statistics(opt['x'], rets)[0], 'g*', markersize=20.0)
    plt.show()

# %%
if __name__ == '__main__':
    # print(download_data())
    dataset = download_data()
    show_data(dataset)
    log_daily_returns = calculate_return(dataset)
    # show_statistics(log_daily_returns)
    # show_mean_variance(log_daily_returns, [0.1, 0.2, 0.3, 0.2, 0.1, 0.1])
    pweights, means, risks = generate_portfolios(log_daily_returns)
    show_portfolios(means, risks)
    optimum = optimize_portfolio(pweights, log_daily_returns)
    print_optimal_portfolio(optimum, log_daily_returns)
    show_optimal_portfolio(optimum, log_daily_returns, means, risks)
# Out:
# [*********************100%***********************]  6 of 6 completed
# Optimal Portfolio:  [0.229 0.    0.    0.531 0.239 0.   ]
# Expected return, volatility and sharpe ratio:  [0.14655582 0.1501267  0.97621421]

# %%
risk_ret_dict_of_quantum
# Out:
# {'returns': 14.294151386888707,
#  'risk': 15.856205845208398,
#  'sharpe_ratio': 0.9014862399259448}

# %% [markdown]
# ## TO Benchmark with Pypfopt

# %%
stocks_df = yf.download(stocks, start = '2013-1-1', end = '2021-12-31')['Adj Close']
stocks_df.head()


# !pip install pyportfolioopt


# from pandas_datareader.data import DataReader
import yfinance as yf
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import plotting
import copy
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns



mu = expected_returns.mean_historical_return(stocks_df)
S = risk_models.sample_cov(stocks_df)
print(mu)

def plot_cum_returns(data, title):    
    daily_cum_returns = 1 + data.dropna().pct_change()
    daily_cum_returns = daily_cum_returns.cumprod()*100
    fig = px.line(daily_cum_returns, title=title)
    return fig
    
fig_cum_returns = plot_cum_returns(stocks_df, 'Cumulative Returns of Individual Stocks Starting with $100')
# fig_cum_returns.show()

corr_df = stocks_df.corr().round(2) # round to 2 decimal places
fig_corr = px.imshow(corr_df, text_auto=True, title = 'Correlation between Stocks')
# fig_corr.show()

def plot_efficient_frontier_and_max_sharpe(mu, S):  
    # Optimize portfolio for maximal Sharpe ratio 
    ef = EfficientFrontier(mu, S)
    fig, ax = plt.subplots(figsize=(8,6))
    ef_max_sharpe = copy.deepcopy(ef)
    plotting.plot_efficient_frontier(ef, ax=ax, show_assets=False)
    # Find the max sharpe portfolio
    ef_max_sharpe.max_sharpe(risk_free_rate=0.02)
    ret_tangent, std_tangent, _ =   ef_max_sharpe.portfolio_performance()
    ax.scatter(std_tangent, ret_tangent, marker="*", s=100, c="r",     label="Max Sharpe")
# Generate random portfolios
    n_samples = 1000
    w = np.random.dirichlet(np.ones(ef.n_assets), n_samples)
    rets = w.dot(ef.expected_returns)
    stds = np.sqrt(np.diag(w @ ef.cov_matrix @ w.T))
    sharpes = rets / stds
    ax.scatter(stds, rets, marker=".", c=sharpes, cmap="viridis_r")
# Output
    ax.set_title("Efficient Frontier with Random Portfolios")
    ax.legend()
    plt.tight_layout()
    plt.show()
    
plot_efficient_frontier_and_max_sharpe(mu, S)

ef = EfficientFrontier(mu, S)
ef.max_sharpe(risk_free_rate=0.02)
weights = ef.clean_weights()
print(weights)

expected_annual_return, annual_volatility, sharpe_ratio = ef.portfolio_performance()
print('Expected annual return: {}%'.format((expected_annual_return*100).round(2)))
print('Annual volatility: {}%'.format((annual_volatility*100).round(2)))
print('Sharpe ratio: {}'.format(sharpe_ratio.round(2)))
# Out:
# [*********************100%***********************]  4 of 4 completed
# AMZN    0.335075
# BAC     0.179450
# CVX     0.052556
# SPY     0.165435
# dtype: float64
# OrderedDict([('AMZN', 0.5056), ('BAC', 0.0), ('CVX', 0.0), ('SPY', 0.4944)])
# Expected annual return: 25.12%
# Annual volatility: 20.86%
# Sharpe ratio: 1.11
